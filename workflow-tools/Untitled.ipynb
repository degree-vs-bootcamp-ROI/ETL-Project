# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df_all = pd.read_csv('../model/indeed_cleaned.csv')

# %%
df_all.reset_index()
df_all.head(150)
# Out:
#      Unnamed: 0                                     job_title  \
# 0             1  Sr. Data Scientist/Machine Learning Engineer
# 1             2                         Senior Data Scientist
# 2             3                     Machine Learning Engineer
# 3             4                                Data Scientist
# 4             5                       Sr Data Scientist, Zoro
# ..          ...                                           ...
# 145         154  Sr. Data Scientist/Machine Learning Engineer
# 146         155                                Data Scientist
# 147         156      Biomedical Data Scientist/Bioinformatics
# 148         157                   Data Scientist- Call Center
# 149         158                 RWD Healthcare Data Scientist
#
#                 company              location                      salary  \
# 0                 aikiu                   NaN   $70,000 - $110,000 a year
# ...

# %%
#df[df.City.str.contains('ville',case=False)]
df_all.dropna(subset = ["location"], inplace=True)
df_all
# Out:
#        Unnamed: 0                                          job_title  \
# 6               7           Biomedical Data Scientist/Bioinformatics
# 7               8                        Data Scientist- Call Center
# 8               9                      RWD Healthcare Data Scientist
# 9              10                        Data Scientist (all levels)
# 10             11  Freelance Data Scientist for an Award-Winning ...
# ...           ...                                                ...
# 17998       18990                                     Data Scientist
# 17999       18991                          Data Scientist I - Remote
# 18000       18992  Freelance Data Scientist for an Award-Winning ...
# 18001       18993                                Data Science Intern
# 18002       18994                                     DATA SCIENTIST
#
#                              company                               location  \
# ...

# %%
df_all[df_all.location.str.contains('New York, NY', case=True)]
# Out:
#        Unnamed: 0                                         job_title  \
# 12             13  Data Scientist/Engineer (Open to remote Workers)
# 45             48  Data Scientist/Engineer (Open to remote Workers)
# 66             70  Data Scientist/Engineer (Open to remote Workers)
# 81             86  Data Scientist/Engineer (Open to remote Workers)
# 102           108  Data Scientist/Engineer (Open to remote Workers)
# ...           ...                                               ...
# 17951       18940                               Data Science Intern
# 17958       18948                          Data Scientist - 70447BR
# 17966       18956                               Data Science Intern
# 17983       18974                               Data Science Intern
# 18001       18993                               Data Science Intern
#
#                   company                                     location  \
# 12     Medidata Solutions  New York, NY 10003 (Flatiron District area)
# ...

# %%
ny_df = df_all[df_all.location.str.contains('New York, NY', case=True)]
ny_df['state'] = 'NY'
# Out:
# C:\Users\busha\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
ca_df = df_all[df_all.location.str.contains(', CA', case=True)]
ca_df['state'] = 'CA'
# Out:
# C:\Users\busha\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
ma_df = df_all[df_all.location.str.contains(', MA', case=True)]
ma_df['state'] = 'MA'
# Out:
# C:\Users\busha\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
il_df = df_all[df_all.location.str.contains(', IL', case=False)]
il_df['state'] = 'IL'

# %%
wa_df = df_all[df_all.location.str.contains(', WA', case=True)]
wa_df['state'] = 'WA'
# Out:
# C:\Users\busha\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
